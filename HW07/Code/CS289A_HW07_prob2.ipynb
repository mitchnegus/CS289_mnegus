# %% [markdown]
# # Homework 7: Problem 2
# ## Low-Rank Approximation

# %% [markdown]
# Programmatic overhead; import numpy, scipy and matplotlib.

# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# Load the face image as an array

# %%
facefile = '/Users/mitch/Documents/Cal/2_2017_Spring/COMPSCI 289A - Intro to Machine Learning/HW07/Data/hw7_data/low-rank_data/face.jpg'
face = ndi.imread(facefile,flatten=True)
plt.imshow(face)
plt.show()
print(np.shape(face))
# Out:
# (330, 280)

# %%
def SVD(matrix):
    U,s,V = np.linalg.svd(matrix)
    return U,s,V

# %%
def diff_frobeniusnorm(matrix1,matrix2):
    dFN = np.linalg.norm(matrix1-matrix2)
    return dFN

# %%
def optimize(rank):

# %%
U,s,V = SVD(face)
